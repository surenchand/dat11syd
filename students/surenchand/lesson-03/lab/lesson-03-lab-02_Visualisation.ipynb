# %% [markdown]
# # ## General Assembly DAT11 Sydney - 26th Feb 2018 ##
#
# ## Visualising Data with Python

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib
import xlrd

# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Read data from a csv
iris_data = pd.read_csv('~/workspace/dat11syd/data/iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#Remove the first 'Unnamed' Column:
iris_data = iris_data.iloc[:,1:6]
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fdbf58760b8>]],
#       dtype=object)

# %%
# Install another Python library using pip
#! pip3 install seaborn # Already installed - don't need to do this!

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
#!pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.4.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="cb49405f-dbdc-4048-80a2-6d5a8bdde779" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("cb49405f-dbdc-4048-80a2-6d5a8bdde779", [{"type": "scatter", "y": [4, 3, 2, 1], "x": [1, 2, 3, 4]}], {"title": "hello world"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="69ed000c-d00e-4df8-a17d-9931905567b9" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("69ed000c-d00e-4df8-a17d-9931905567b9", [{"colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "hoverinfo": "none", "type": "heatmap", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]], "showscale": false, "opacity": 0.75}], {"xaxis": {"showticklabels": false, "gridwidth": 2, "ticks": "", "zeroline": false, "tick0": -0.5, "dtick": 1}, "margin": {"t": 0, "r": 0, "b": 0, "l": 0}, "yaxis": {"showticklabels": false, "gridwidth": 2, "autorange": "reversed", "ticks": "", "zeroline": false, "tick0": 0.5, "dtick": 1}, "annotations": [{"yref": "y1", "text": "<b>School</b>", "align": "left", "xanchor": "left", "y": 0, "xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#ffffff"}}, {"yref": "y1", "text": "<b>Women</b>", "align": "left", "xanchor": "left", "y": 0, "xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#ffffff"}}, {"yref": "y1", "text": "<b>Men</b>", "align": "left", "xanchor": "left", "y": 0, "xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#ffffff"}}, {"yref": "y1", "text": "<b>Gap</b>", "align": "left", "xanchor": "left", "y": 0, "xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#ffffff"}}, {"yref": "y1", "text": "MIT", "align": "left", "xanchor": "left", "y": 1, "xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}}, {"yref": "y1", "text": "94", "align": "left", "xanchor": "left", "y": 1, "xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "152", "align": "left", "xanchor": "left", "y": 1, "xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "58", "align": "left", "xanchor": "left", "y": 1, "xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "Stanford", "align": "left", "xanchor": "left", "y": 2, "xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}}, {"yref": "y1", "text": "96", "align": "left", "xanchor": "left", "y": 2, "xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "151", "align": "left", "xanchor": "left", "y": 2, "xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "55", "align": "left", "xanchor": "left", "y": 2, "xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "Harvard", "align": "left", "xanchor": "left", "y": 3, "xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}}, {"yref": "y1", "text": "112", "align": "left", "xanchor": "left", "y": 3, "xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "165", "align": "left", "xanchor": "left", "y": 3, "xref": "x1", "showarrow": false, "x": 1.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "53", "align": "left", "xanchor": "left", "y": 3, "xref": "x1", "showarrow": false, "x": 2.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "U.Penn", "align": "left", "xanchor": "left", "y": 4, "xref": "x1", "showarrow": false, "x": -0.45, "font": {"color": "#000000"}}, {"yref": "y1", "text": "92", "align": "left", "xanchor": "left", "y": 4, "xref": "x1", "showarrow": false, "x": 0.55, "font": {"color": "#000000"}}, {"yref": "y1", "text": "141", "align": "left", "xanchor": "left", "y": 4, "x ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="1205130d-d83c-4bfe-a330-7ca243ac43ee" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("1205130d-d83c-4bfe-a330-7ca243ac43ee", [{"type": "bar", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="96ad05ae-430b-4c91-9678-cbf140f4a816" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("96ad05ae-430b-4c91-9678-cbf140f4a816", [{"name": "Women", "type": "bar", "marker": {"color": "#ffcdd2"}, "y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}, {"name": "Men", "type": "bar", "marker": {"color": "#A2D5F2"}, "y": [152, 151, 165, 141, 137, 118, 131, 112, 114, 119, 124, 114, 94, 100, 107, 84, 92, 88, 82, 78, 81], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}, {"name": "Gap", "type": "bar", "marker": {"color": "#59606D"}, "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {"xaxis": {"title": "School"}, "yaxis": {"title": "Salary (in thousands)"}, "title": "Average Earnings for Graduates"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Scatter plot with heatmap
x = np.random.randn(2000)
y = np.random.randn(2000)
plotly.offline.iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="3a0b6e3e-178d-4846-9c08-135f988ca214" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("3a0b6e3e-178d-4846-9c08-135f988ca214", [{"contours": {"coloring": "heatmap"}, "type": "histogram2dcontour", "y": [-0.3126048585430898, -0.39835614138648695, -0.9249470495311182, -0.445379674005162, 1.8377546993944593, 0.3676941884250322, 0.3926248830812775, -0.8040077465183882, 1.6503933104001434, 1.2306101453264013, 0.15246784245066905, -0.2183021259601821, -1.1144232039753268, 0.3340345338172897, -0.7353706880791008, 0.22977760806660572, 1.101629585179353, 0.5660358746082133, 0.746143741581031, -0.448870588569218, 1.2306023831126085, 0.0018909514596679845, 2.1395338264457444, -0.27935770782052793, -0.1651494326293955, 0.5175103306566379, 0.43837201907595513, -0.796203996529852, -1.4569507780872097, -0.4323416212028563, 0.15968782701337067, 1.0587273949140812, 1.2839689614968626, 0.9569885528555886, -0.16295469349256414, 0.4312832653602972, 2.1170624991120155, 1.3446886435763963, 1.1419370597663225, 0.03391223472895931, -0.6398818987164189, 0.6429832623969353, 0.10747837902290118, -1.0102515830019023, 0.10758434879883366, -0.5037243797185282, -0.568886205428996, 0.7521430570264344, 1.6922775944127701, -2.172231509860216, 0.40914932952173144, -2.4329241958169345, 0.1839598879291867, 1.9322666880760517, -0.7501352688623014, 0.8097096821563499, 0.6678529892174103, 1.6134957202431557, 0.658736554597914, -1.4149419414650826, 0.013660244485143387, -0.24953604627143594, -1.5306335838699574, -1.0025513540017685, -0.1961688340684651, 0.11500602800525776, 0.4168789844669737, 0.15396350538821385, -2.013404345974863, -1.0511035106334252, 0.38820624521584307, -0.6057894701602601, -1.5849588210907455, -1.7553941051132043, 0.3784196604130256, -1.417453461092857, 0.2519785248156759, 0.11191776774920706, -0.281024919789016, 0.7497795136065148, 1.4316841081215985, -0.275486235656124, 1.4590093643927864, 0.3571014385402095, -1.0453450683792471, 0.7677925170242333, 0.6711029098260226, -0.7448655531508409, 1.2719435299986097, 1.2921004711895108, 0.08195859853283931, 1.6569840654174124, 0.45390089895800667, 0.9113478583087589, -1.1148740622633386, -1.8430425551417318, -0.43236182006263885, -0.0704859251115917, -0.5370121794301378, 1.4375585116542824, 0.37052116377779265, -1.9772652080118773, 0.42317579428988583, -0.14516017182241503, 0.7087394276633087, -1.9583078958477598, -1.5514973025326833, 0.06695680645370729, 1.783157649871958, -0.4100308933574439, 0.27758726061367545, 0.10403133725347151, 0.49659280554575763, 1.1978982046039506, 0.8456775496865215, 0.8203295031711257, 0.24331985689453253, 0.18212704475898656, -0.532205288434802, 0.04538362482058113, 1.2639449567505738, 0.4779116567065338, -0.8156750132860929, 0.5847359916497051, -0.601042761065203, 0.030924028031212136, -1.8192926885899974, 0.747339494564155, -1.283746473554112, 0.21396475088413017, -1.6763895652989558, 0.6091934492832638, 0.33710464483457964, -0.6042555894758372, 1.2748023963946806, -1.07193794395661, -0.2220667941075238, 0.9721350060598628, 0.10058651940102448, -1.7641118697022038, -0.6912772804699652, 0.9917169478736441, -0.5069235947928127, -0.5038959321456297, -1.6352126602095431, -0.5289635183593261, -0.42427210936462706, -0.8577363075441916, -1.9967330372021148, -0.37653619526455023, -0.7061500957363278, 2.39541321975022, -1.7662143545088942, -1.6916852533066464, -0.8929863367745348, 0.37077947705101755, -0.17036381255957378, -0.007507913472837993, -1.876900307242163, 1.316455309434115, 0.18393213047710266, 1.006263743025025, -0.007156758042533011, 0.7562392747691004, 1.452762674155302, 0.14127861506806652, 0.33695742090736663, -0.574738781934008, 0.3985540405574223, 1.3675510205569708, -0.33228815770893105, -0.3365169264754728, -0.09380675593402096, -0.6074583437677419, -1.02041988112905 ...

# %%
# Mapping
df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df_airports.head()

df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()

airports = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_airports['long'],
        lat = df_airports['lat'],
        hoverinfo = 'text',
        text = df_airports['airport'],
        mode = 'markers',
        marker = dict(
            size=2,
            color='rgb(255, 0, 0)',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]

flight_paths = []
for i in range( len( df_flight_paths ) ):
    flight_paths.append(
        dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = [ df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i] ],
            lat = [ df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i] ],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            ),
            opacity = float(df_flight_paths['cnt'][i])/float(df_flight_paths['cnt'].max()),
        )
    )

layout = dict(
        title = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)',
        showlegend = False,
        height = 800,
        geo = dict(
            scope='north america',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )

fig = dict( data=flight_paths + airports, layout=layout )

plotly.offline.iplot(fig)
# Out:
# <div id="9e4cbf18-0017-404a-bf4a-a4fcd0c911e8" style="height: 800px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("9e4cbf18-0017-404a-bf4a-a4fcd0c911e8", [{"lat": [32.89595056, 35.04022222], "locationmode": "USA-states", "lon": [-97.0372, -106.6091944], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.48577680525164113}, {"lat": [41.979595, 30.19453278], "locationmode": "USA-states", "lon": [-87.90446417, -97.66987194], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.18161925601750548}, {"lat": [32.89595056, 41.93887417], "locationmode": "USA-states", "lon": [-97.0372, -72.68322833], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.1772428884026258}, {"lat": [18.43941667, 41.93887417], "locationmode": "USA-states", "lon": [-66.00183333, -72.68322833], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.061269146608315096}, {"lat": [32.89595056, 33.56294306], "locationmode": "USA-states", "lon": [-97.0372, -86.75354972], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.1838074398249453}, {"lat": [25.79325, 36.12447667], "locationmode": "USA-states", "lon": [-80.29055556, -86.67818222], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.061269146608315096}, {"lat": [32.89595056, 42.3643475], "locationmode": "USA-states", "lon": [-97.0372, -71.00517917], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.4617067833698031}, {"lat": [25.79325, 42.3643475], "locationmode": "USA-states", "lon": [-80.29055556, -71.00517917], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.4288840262582057}, {"lat": [41.979595, 42.3643475], "locationmode": "USA-states", "lon": [-87.90446417, -71.00517917], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.47045951859956237}, {"lat": [18.43941667, 42.3643475], "locationmode": "USA-states", "lon": [-66.00183333, -71.00517917], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.061269146608315096}, {"lat": [18.33730556, 42.3643475], "locationmode": "USA-states", "lon": [-64.97336111, -71.00517917], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.04814004376367615}, {"lat": [25.79325, 39.17540167], "locationmode": "USA-states", "lon": [-80.29055556, -76.66819833], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.12253829321663019}, {"lat": [18.43941667, 39.17540167], "locationmode": "USA-states", "lon": [-66.00183333, -76.66819833], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.061269146608315096}, {"lat": [32.89595056, 35.21401111], "locationmode": "USA-states", "lon": [-97.0372, -80.94312583], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.3938730853391685}, {"lat": [32.89595056, 38.80580556], "locationmode": "USA-states", "lon": [-97.0372, -104.70025], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.3041575492341357}, {"lat": [32.89595056, 39.90237583], "locationmode": "USA-states", "lon": [-97.0372, -84.219375], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.1137855579868709}, {"lat": [32.89595056, 38.85208333], "locationmode": "USA-states", "lon": [-97.0372, -77.03772222], "type": "scattergeo", "mode": "lines", "line": {"width": 1, "color": "red"}, "opacity": 0.6433260393873085}, {"lat": [25.79325, 39.85840806], "locationmode": "USA-states", "lon": [-80.29055556, -104.6670019], "type": "scat ...
