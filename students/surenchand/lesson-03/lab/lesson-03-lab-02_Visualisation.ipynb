# %% [markdown]
# # ## General Assembly DAT11 Sydney - 26th Feb 2018 ##
#
# ## Visualising Data with Python

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib
import xlrd

# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Read data from a csv
iris_data = pd.read_csv('~/workspace/dat11syd/data/iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#Remove the first 'Unnamed' Column:
iris_data = iris_data.iloc[:,1:6]
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f16cd9106a0>]],
#       dtype=object)

# %%
# Install another Python library using pip
#! pip3 install seaborn # Already installed - don't need to do this!

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
#!pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.4.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="40597144-8d5d-4c96-a97a-797753f20216" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("40597144-8d5d-4c96-a97a-797753f20216", [{"type": "scatter", "x": [1, 2, 3, 4], "y": [4, 3, 2, 1]}], {"title": "hello world"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="eba5d6ee-ae2f-475d-a002-2319f496411a" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("eba5d6ee-ae2f-475d-a002-2319f496411a", [{"hoverinfo": "none", "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]], "type": "heatmap", "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "showscale": false, "opacity": 0.75}], {"height": 710, "margin": {"r": 0, "l": 0, "b": 0, "t": 0}, "xaxis": {"dtick": 1, "zeroline": false, "gridwidth": 2, "tick0": -0.5, "ticks": "", "showticklabels": false}, "yaxis": {"dtick": 1, "zeroline": false, "gridwidth": 2, "autorange": "reversed", "tick0": 0.5, "ticks": "", "showticklabels": false}, "annotations": [{"y": 0, "yref": "y1", "font": {"color": "#ffffff"}, "xref": "x1", "text": "<b>School</b>", "xanchor": "left", "x": -0.45, "align": "left", "showarrow": false}, {"y": 0, "yref": "y1", "font": {"color": "#ffffff"}, "xref": "x1", "text": "<b>Women</b>", "xanchor": "left", "x": 0.55, "align": "left", "showarrow": false}, {"y": 0, "yref": "y1", "font": {"color": "#ffffff"}, "xref": "x1", "text": "<b>Men</b>", "xanchor": "left", "x": 1.55, "align": "left", "showarrow": false}, {"y": 0, "yref": "y1", "font": {"color": "#ffffff"}, "xref": "x1", "text": "<b>Gap</b>", "xanchor": "left", "x": 2.55, "align": "left", "showarrow": false}, {"y": 1, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "MIT", "xanchor": "left", "x": -0.45, "align": "left", "showarrow": false}, {"y": 1, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "94", "xanchor": "left", "x": 0.55, "align": "left", "showarrow": false}, {"y": 1, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "152", "xanchor": "left", "x": 1.55, "align": "left", "showarrow": false}, {"y": 1, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "58", "xanchor": "left", "x": 2.55, "align": "left", "showarrow": false}, {"y": 2, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "Stanford", "xanchor": "left", "x": -0.45, "align": "left", "showarrow": false}, {"y": 2, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "96", "xanchor": "left", "x": 0.55, "align": "left", "showarrow": false}, {"y": 2, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "151", "xanchor": "left", "x": 1.55, "align": "left", "showarrow": false}, {"y": 2, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "55", "xanchor": "left", "x": 2.55, "align": "left", "showarrow": false}, {"y": 3, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "Harvard", "xanchor": "left", "x": -0.45, "align": "left", "showarrow": false}, {"y": 3, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "112", "xanchor": "left", "x": 0.55, "align": "left", "showarrow": false}, {"y": 3, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "165", "xanchor": "left", "x": 1.55, "align": "left", "showarrow": false}, {"y": 3, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "53", "xanchor": "left", "x": 2.55, "align": "left", "showarrow": false}, {"y": 4, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "U.Penn", "xanchor": "left", "x": -0.45, "align": "left", "showarrow": false}, {"y": 4, "yref": "y1", "font": {"color": "#000000"}, "xref": "x1", "text": "92", "xanchor": "left", "x": 0.55, "align": "left", "showarrow": false}, {"y": 4, "yref": "y1", "font": {"color": "#000000"}, "xref":  ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="6b3aa04e-b2ee-44fd-97c0-436d8cee3bc9" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6b3aa04e-b2ee-44fd-97c0-436d8cee3bc9", [{"type": "bar", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="d393fef8-e378-47e6-965d-8735e6ef77b1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d393fef8-e378-47e6-965d-8735e6ef77b1", [{"type": "bar", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "name": "Women", "marker": {"color": "#ffcdd2"}}, {"type": "bar", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "y": [152, 151, 165, 141, 137, 118, 131, 112, 114, 119, 124, 114, 94, 100, 107, 84, 92, 88, 82, 78, 81], "name": "Men", "marker": {"color": "#A2D5F2"}}, {"type": "bar", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"], "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "name": "Gap", "marker": {"color": "#59606D"}}], {"xaxis": {"title": "School"}, "yaxis": {"title": "Salary (in thousands)"}, "title": "Average Earnings for Graduates"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
# Scatter plot with heatmap
x = np.random.randn(2000)
y = np.random.randn(2000)
plotly.offline.iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="c7d1f95c-56c5-4ef1-bb82-489a3a06affd" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c
# %%
# Mapping
df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df_airports.head()

df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()

airports = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_airports['long'],
        lat = df_airports['lat'],
        hoverinfo = 'text',
        text = df_airports['airport'],
        mode = 'markers',
        marker = dict(
            size=2,
            color='rgb(255, 0, 0)',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]

flight_paths = []
for i in range( len( df_flight_paths ) ):
    flight_paths.append(
        dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = [ df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i] ],
            lat = [ df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i] ],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            ),
            opacity = float(df_flight_paths['cnt'][i])/float(df_flight_paths['cnt'].max()),
        )
    )

layout = dict(
        title = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)',
        showlegend = False,
        height = 800,
        geo = dict(
            scope='north america',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )

fig = dict( data=flight_paths + airports, layout=layout )

plotly.offline.iplot(fig)
# Out:
# <div id="48adb968-40ea-4124-8efe-e30376ac9712" style="height: 800px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("48adb968-40ea-4124-8efe-e30376ac9712", [{"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -106.6091944], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 35.04022222], "opacity": 0.48577680525164113}, {"line": {"width": 1, "color": "red"}, "lon": [-87.90446417, -97.66987194], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [41.979595, 30.19453278], "opacity": 0.18161925601750548}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -72.68322833], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 41.93887417], "opacity": 0.1772428884026258}, {"line": {"width": 1, "color": "red"}, "lon": [-66.00183333, -72.68322833], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [18.43941667, 41.93887417], "opacity": 0.061269146608315096}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -86.75354972], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 33.56294306], "opacity": 0.1838074398249453}, {"line": {"width": 1, "color": "red"}, "lon": [-80.29055556, -86.67818222], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [25.79325, 36.12447667], "opacity": 0.061269146608315096}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -71.00517917], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 42.3643475], "opacity": 0.4617067833698031}, {"line": {"width": 1, "color": "red"}, "lon": [-80.29055556, -71.00517917], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [25.79325, 42.3643475], "opacity": 0.4288840262582057}, {"line": {"width": 1, "color": "red"}, "lon": [-87.90446417, -71.00517917], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [41.979595, 42.3643475], "opacity": 0.47045951859956237}, {"line": {"width": 1, "color": "red"}, "lon": [-66.00183333, -71.00517917], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [18.43941667, 42.3643475], "opacity": 0.061269146608315096}, {"line": {"width": 1, "color": "red"}, "lon": [-64.97336111, -71.00517917], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [18.33730556, 42.3643475], "opacity": 0.04814004376367615}, {"line": {"width": 1, "color": "red"}, "lon": [-80.29055556, -76.66819833], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [25.79325, 39.17540167], "opacity": 0.12253829321663019}, {"line": {"width": 1, "color": "red"}, "lon": [-66.00183333, -76.66819833], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [18.43941667, 39.17540167], "opacity": 0.061269146608315096}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -80.94312583], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 35.21401111], "opacity": 0.3938730853391685}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -104.70025], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 38.80580556], "opacity": 0.3041575492341357}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -84.219375], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 39.90237583], "opacity": 0.1137855579868709}, {"line": {"width": 1, "color": "red"}, "lon": [-97.0372, -77.03772222], "mode": "lines", "type": "scattergeo", "locationmode": "USA-states", "lat": [32.89595056, 38.85208333], "opacity": 0.6433260393873085}, {"line": {"width": 1, "color": "red"}, "lon": [-80.29055556, -104.6670019], "mode": "lines", "type": "scattergeo" ...
