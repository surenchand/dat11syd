# %% [markdown]
# # ## General Assembly DAT11 Sydney - 26th Feb 2018 ##
#
# ## Visualising Data with Python

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib
import xlrd

# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Read data from a csv
iris_data = pd.read_csv('~/workspace/dat11syd/data/iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#Remove the first 'Unnamed' Column:
iris_data = iris_data.iloc[:,1:6]
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f81c9ba0b00>]],
#       dtype=object)

# %%
# Install another Python library using pip
#! pip3 install seaborn # Already installed - don't need to do this!

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
#!pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.4.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="a73c1621-4b98-46aa-8973-22197472efcf" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("a73c1621-4b98-46aa-8973-22197472efcf", [{"type": "scatter", "y": [4, 3, 2, 1], "x": [1, 2, 3, 4]}], {"title": "hello world"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="c17c60f6-076e-4ad4-9c6b-47e65b90b97c" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c17c60f6-076e-4ad4-9c6b-47e65b90b97c", [{"z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]], "opacity": 0.75, "hoverinfo": "none", "showscale": false, "type": "heatmap", "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]]}], {"height": 710, "margin": {"l": 0, "r": 0, "b": 0, "t": 0}, "xaxis": {"dtick": 1, "gridwidth": 2, "zeroline": false, "showticklabels": false, "ticks": "", "tick0": -0.5}, "yaxis": {"dtick": 1, "gridwidth": 2, "ticks": "", "autorange": "reversed", "zeroline": false, "showticklabels": false, "tick0": 0.5}, "annotations": [{"xref": "x1", "x": -0.45, "showarrow": false, "font": {"color": "#ffffff"}, "text": "<b>School</b>", "align": "left", "xanchor": "left", "y": 0, "yref": "y1"}, {"xref": "x1", "x": 0.55, "showarrow": false, "font": {"color": "#ffffff"}, "text": "<b>Women</b>", "align": "left", "xanchor": "left", "y": 0, "yref": "y1"}, {"xref": "x1", "x": 1.55, "showarrow": false, "font": {"color": "#ffffff"}, "text": "<b>Men</b>", "align": "left", "xanchor": "left", "y": 0, "yref": "y1"}, {"xref": "x1", "x": 2.55, "showarrow": false, "font": {"color": "#ffffff"}, "text": "<b>Gap</b>", "align": "left", "xanchor": "left", "y": 0, "yref": "y1"}, {"xref": "x1", "x": -0.45, "showarrow": false, "font": {"color": "#000000"}, "text": "MIT", "align": "left", "xanchor": "left", "y": 1, "yref": "y1"}, {"xref": "x1", "x": 0.55, "showarrow": false, "font": {"color": "#000000"}, "text": "94", "align": "left", "xanchor": "left", "y": 1, "yref": "y1"}, {"xref": "x1", "x": 1.55, "showarrow": false, "font": {"color": "#000000"}, "text": "152", "align": "left", "xanchor": "left", "y": 1, "yref": "y1"}, {"xref": "x1", "x": 2.55, "showarrow": false, "font": {"color": "#000000"}, "text": "58", "align": "left", "xanchor": "left", "y": 1, "yref": "y1"}, {"xref": "x1", "x": -0.45, "showarrow": false, "font": {"color": "#000000"}, "text": "Stanford", "align": "left", "xanchor": "left", "y": 2, "yref": "y1"}, {"xref": "x1", "x": 0.55, "showarrow": false, "font": {"color": "#000000"}, "text": "96", "align": "left", "xanchor": "left", "y": 2, "yref": "y1"}, {"xref": "x1", "x": 1.55, "showarrow": false, "font": {"color": "#000000"}, "text": "151", "align": "left", "xanchor": "left", "y": 2, "yref": "y1"}, {"xref": "x1", "x": 2.55, "showarrow": false, "font": {"color": "#000000"}, "text": "55", "align": "left", "xanchor": "left", "y": 2, "yref": "y1"}, {"xref": "x1", "x": -0.45, "showarrow": false, "font": {"color": "#000000"}, "text": "Harvard", "align": "left", "xanchor": "left", "y": 3, "yref": "y1"}, {"xref": "x1", "x": 0.55, "showarrow": false, "font": {"color": "#000000"}, "text": "112", "align": "left", "xanchor": "left", "y": 3, "yref": "y1"}, {"xref": "x1", "x": 1.55, "showarrow": false, "font": {"color": "#000000"}, "text": "165", "align": "left", "xanchor": "left", "y": 3, "yref": "y1"}, {"xref": "x1", "x": 2.55, "showarrow": false, "font": {"color": "#000000"}, "text": "53", "align": "left", "xanchor": "left", "y": 3, "yref": "y1"}, {"xref": "x1", "x": -0.45, "showarrow": false, "font": {"color": "#000000"}, "text": "U.Penn", "align": "left", "xanchor": "left", "y": 4, "yref": "y1"}, {"xref": "x1", "x": 0.55, "showarrow": false, "font": {"color": "#000000"}, "text": "92", "align": "left", "xanchor": "left", "y": 4, "yref": "y1"}, {"xref": "x1", "x": 1.55, "showarrow": false, "font": {"color ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="e0219619-635e-4438-a8fc-98ba80ddb452" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e0219619-635e-4438-a8fc-98ba80ddb452", [{"type": "bar", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="0ae3ffb7-1219-4c68-ae82-d55c1dd02da6" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("0ae3ffb7-1219-4c68-ae82-d55c1dd02da6", [{"marker": {"color": "#ffcdd2"}, "type": "bar", "y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"],