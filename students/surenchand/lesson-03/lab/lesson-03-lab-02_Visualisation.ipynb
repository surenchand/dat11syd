# %% [markdown]
# # ## General Assembly DAT11 Sydney - 26th Feb 2018 ##
#
# ## Visualising Data with Python

# %%
# Load the Iris dataset from CSV URL
# 1. Import the required libraries
import numpy as np
import pandas as pd
import urllib
import xlrd

# Display the plots in the notebook with the following command
# %matplotlib inline
# Import the graphing libraries we will use
import matplotlib.pyplot as plt

# %% [markdown]
# ### Visualising data in Python
# This Section will deal with visualising data in Python. We will cover different graph types and how to interpret them.

# %%
# Read data from a csv
iris_data = pd.read_csv('~/workspace/dat11syd/data/iris.csv')
iris_data.head()
# Out:
#    Unnamed: 0  sepal_length  sepal_width  petal_length  petal_width species
# 0           0           5.1          3.5           1.4          0.2  setosa
# 1           1           4.9          3.0           1.4          0.2  setosa
# 2           2           4.7          3.2           1.3          0.2  setosa
# 3           3           4.6          3.1           1.5          0.2  setosa
# 4           4           5.0          3.6           1.4          0.2  setosa

# %%
#Remove the first 'Unnamed' Column:
iris_data = iris_data.iloc[:,1:6]
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_data[['sepal_width']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f81c9ba0b00>]],
#       dtype=object)

# %%
# Install another Python library using pip
#! pip3 install seaborn # Already installed - don't need to do this!

# %%
import seaborn as sns
sns.set(color_codes=True)

# %%
iris_data.loc[iris_data['species'] == 'setosa', 'sepal_width'].hist()

# %%
# Draw a Scatterplot showing sepal width and length
sns.lmplot(x='sepal_width', y="sepal_length", hue="species", data=iris_data, fit_reg=True)
#iris_data.plot(kind='scatter', x='sepal_width', y='sepal_length');

# %%
sns.jointplot(x="sepal_width", y="sepal_length", data=iris_data);

# %%
sns.pairplot(iris_data);

# %%
sns.pairplot(iris_data, hue='species');

# %%
from pandas.plotting import parallel_coordinates
parallel_coordinates (iris_data, 'species')

# %% [markdown]
# ### Plotly
# A nice open source library for interactive visualisations

# %%
# To run any command at the system shell, simply prefix it with !
# pip won't work from inside python without it
#!pip install plotly --upgrade

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot

print(__version__) # requires version >= 1.9.0
# Out:
# 2.4.1

# %%
import plotly
from plotly.graph_objs import Scatter, Layout

plotly.offline.init_notebook_mode(connected=True)

plotly.offline.iplot({
    "data": [Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": Layout(title="hello world")
})
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# <div id="d57f19a8-9cf0-435b-bf7f-d7fc95585760" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d57f19a8-9cf0-435b-bf7f-d7fc95585760", [{"type": "scatter", "x": [1, 2, 3, 4], "y": [4, 3, 2, 1]}], {"title": "hello world"}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
import plotly as py
import plotly.figure_factory as ff
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/plotly/datasets/master/school_earnings.csv")

table = ff.create_table(df)
plotly.offline.iplot(table, filename='jupyter/table1')
# Out:
# <div id="8d8429e0-fa13-4911-8a3c-c8878d742f91" style="height: 710px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("8d8429e0-fa13-4911-8a3c-c8878d742f91", [{"opacity": 0.75, "hoverinfo": "none", "colorscale": [[0, "#00083e"], [0.5, "#ededee"], [1, "#ffffff"]], "showscale": false, "z": [[0, 0, 0, 0], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5], [1, 1, 1, 1], [0.5, 0.5, 0.5, 0.5]], "type": "heatmap"}], {"yaxis": {"dtick": 1, "ticks": "", "showticklabels": false, "tick0": 0.5, "gridwidth": 2, "zeroline": false, "autorange": "reversed"}, "xaxis": {"dtick": 1, "ticks": "", "showticklabels": false, "tick0": -0.5, "gridwidth": 2, "zeroline": false}, "height": 710, "annotations": [{"align": "left", "xref": "x1", "font": {"color": "#ffffff"}, "x": -0.45, "yref": "y1", "showarrow": false, "y": 0, "text": "<b>School</b>", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#ffffff"}, "x": 0.55, "yref": "y1", "showarrow": false, "y": 0, "text": "<b>Women</b>", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#ffffff"}, "x": 1.55, "yref": "y1", "showarrow": false, "y": 0, "text": "<b>Men</b>", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#ffffff"}, "x": 2.55, "yref": "y1", "showarrow": false, "y": 0, "text": "<b>Gap</b>", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": -0.45, "yref": "y1", "showarrow": false, "y": 1, "text": "MIT", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 0.55, "yref": "y1", "showarrow": false, "y": 1, "text": "94", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 1.55, "yref": "y1", "showarrow": false, "y": 1, "text": "152", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 2.55, "yref": "y1", "showarrow": false, "y": 1, "text": "58", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": -0.45, "yref": "y1", "showarrow": false, "y": 2, "text": "Stanford", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 0.55, "yref": "y1", "showarrow": false, "y": 2, "text": "96", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 1.55, "yref": "y1", "showarrow": false, "y": 2, "text": "151", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 2.55, "yref": "y1", "showarrow": false, "y": 2, "text": "55", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": -0.45, "yref": "y1", "showarrow": false, "y": 3, "text": "Harvard", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 0.55, "yref": "y1", "showarrow": false, "y": 3, "text": "112", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 1.55, "yref": "y1", "showarrow": false, "y": 3, "text": "165", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 2.55, "yref": "y1", "showarrow": false, "y": 3, "text": "53", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": -0.45, "yref": "y1", "showarrow": false, "y": 4, "text": "U.Penn", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 0.55, "yref": "y1", "showarrow": false, "y": 4, "text": "92", "xanchor": "left"}, {"align": "left", "xref": "x1", "font": {"color": "#000000"}, "x": 1.55, "yref": "y1", "showarrow": false ...

# %%
import plotly.plotly as py
from plotly.graph_objs import *

data = [Bar(x=df.School,
            y=df.Gap)]

plotly.offline.iplot(data, filename='jupyter/basic_bar')
# Out:
# <div id="e0219619-635e-4438-a8fc-98ba80ddb452" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("e0219619-635e-4438-a8fc-98ba80ddb452", [{"type": "bar", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %%
import plotly.plotly as py
from plotly.graph_objs import *

trace_women = Bar(x=df.School,
                  y=df.Women,
                  name='Women',
                  marker=dict(color='#ffcdd2'))

trace_men = Bar(x=df.School,
                y=df.Men,
                name='Men',
                marker=dict(color='#A2D5F2'))

trace_gap = Bar(x=df.School,
                y=df.Gap,
                name='Gap',
                marker=dict(color='#59606D'))

data = [trace_women, trace_men, trace_gap]
layout = Layout(title="Average Earnings for Graduates",
                xaxis=dict(title='School'),
                yaxis=dict(title='Salary (in thousands)'))
fig = Figure(data=data, layout=layout)

plotly.offline.iplot(fig, filename='jupyter/styled_bar')
# Out:
# <div id="ffb4b8c9-065a-472c-b44d-caff415f6651" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("ffb4b8c9-065a-472c-b44d-caff415f6651", [{"type": "bar", "y": [94, 96, 112, 92, 90, 78, 94, 76, 79, 86, 93, 84, 67, 73, 80, 62, 72, 71, 68, 64, 72], "marker": {"color": "#ffcdd2"}, "name": "Women", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}, {"type": "bar", "y": [152, 151, 165, 141, 137, 118, 131, 112, 114, 119, 124, 114, 94, 100, 107, 84, 92, 88, 82, 78, 81], "marker": {"color": "#A2D5F2"}, "name": "Men", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}, {"type": "bar", "y": [58, 55, 53, 49, 47, 40, 37, 36, 35, 33, 31, 30, 27, 27, 27, 22, 20, 17, 14, 14, 9], "marker": {"color": "#59606D"}, "name": "Gap", "x": ["MIT", "Stanford", "Harvard", "U.Penn", "Princeton", "Chicago", "Georgetown", "Tufts", "Yale", "Columbia", "Duke", "Dartmouth", "NYU", "Notre Dame", "Cornell", "Michigan", "Brown", "Berkeley", "Emory", "UCLA", "SoCal"]}], {"title": "Average Earnings for Graduates", "yaxis": {"title": "Salary (in thousands)"}, "xaxis": {"title": "School"}}, {"linkText": "Export to plot.ly", "showLink": true})});</script>

# %%
# Scatter plot with heatmap
x = np.random.randn(2000)
y = np.random.randn(2000)
plotly.offline.iplot([Histogram2dContour(x=x, y=y, contours=Contours(coloring='heatmap')),
       Scatter(x=x, y=y, mode='markers', marker=Marker(color='white', size=3, opacity=0.3))], show_link=False)
# Out:
# <div id="6398c21b-a5c8-4c5c-830e-d4aba136f6fe" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("
288704923754749, -0.453454811180996, -1.9106345956396307, -0.9093783694005078, 0.3220555361379738, 0.17100835733683808, -1.1306097851511008, -0.612542011505516, 0.503554012708994, 1.0852605803806614, -0.3210951327926761, 0.5001165902715643, 1.590052119540283, -0.26407872942287985, -0.7665580605238624, 1.3987937380389701, 1.2229198016789007, -0.35666775607116097, -1.3268106017832693, -0.9470988157056527, 0.34613394044558 ...

# %%
# Mapping
df_airports = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_us_airport_traffic.csv')
df_airports.head()

df_flight_paths = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/2011_february_aa_flight_paths.csv')
df_flight_paths.head()

airports = [ dict(
        type = 'scattergeo',
        locationmode = 'USA-states',
        lon = df_airports['long'],
        lat = df_airports['lat'],
        hoverinfo = 'text',
        text = df_airports['airport'],
        mode = 'markers',
        marker = dict(
            size=2,
            color='rgb(255, 0, 0)',
            line = dict(
                width=3,
                color='rgba(68, 68, 68, 0)'
            )
        ))]

flight_paths = []
for i in range( len( df_flight_paths ) ):
    flight_paths.append(
        dict(
            type = 'scattergeo',
            locationmode = 'USA-states',
            lon = [ df_flight_paths['start_lon'][i], df_flight_paths['end_lon'][i] ],
            lat = [ df_flight_paths['start_lat'][i], df_flight_paths['end_lat'][i] ],
            mode = 'lines',
            line = dict(
                width = 1,
                color = 'red',
            ),
            opacity = float(df_flight_paths['cnt'][i])/float(df_flight_paths['cnt'].max()),
        )
    )

layout = dict(
        title = 'Feb. 2011 American Airline flight paths<br>(Hover for airport names)',
        showlegend = False,
        height = 800,
        geo = dict(
            scope='north america',
            projection=dict( type='azimuthal equal area' ),
            showland = True,
            landcolor = 'rgb(243, 243, 243)',
            countrycolor = 'rgb(204, 204, 204)',
        ),
    )

fig = dict( data=flight_paths + airports, layout=layout )

plotly.offline.iplot(fig)
# Out:
# <div id="b85a67db-825f-4f90-a2e2-7bfd5cfc5de5" style="height: 800px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("b85a67db-825f-4f90-a2e2-7bfd5cfc5de5", [{"mode": "lines", "opacity": 0.48577680525164113, "lat": [32.89595056, 35.04022222], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -106.6091944], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.18161925601750548, "lat": [41.979595, 30.19453278], "line": {"color": "red", "width": 1}, "lon": [-87.90446417, -97.66987194], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.1772428884026258, "lat": [32.89595056, 41.93887417], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -72.68322833], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.061269146608315096, "lat": [18.43941667, 41.93887417], "line": {"color": "red", "width": 1}, "lon": [-66.00183333, -72.68322833], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.1838074398249453, "lat": [32.89595056, 33.56294306], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -86.75354972], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.061269146608315096, "lat": [25.79325, 36.12447667], "line": {"color": "red", "width": 1}, "lon": [-80.29055556, -86.67818222], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.4617067833698031, "lat": [32.89595056, 42.3643475], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -71.00517917], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.4288840262582057, "lat": [25.79325, 42.3643475], "line": {"color": "red", "width": 1}, "lon": [-80.29055556, -71.00517917], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.47045951859956237, "lat": [41.979595, 42.3643475], "line": {"color": "red", "width": 1}, "lon": [-87.90446417, -71.00517917], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.061269146608315096, "lat": [18.43941667, 42.3643475], "line": {"color": "red", "width": 1}, "lon": [-66.00183333, -71.00517917], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.04814004376367615, "lat": [18.33730556, 42.3643475], "line": {"color": "red", "width": 1}, "lon": [-64.97336111, -71.00517917], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.12253829321663019, "lat": [25.79325, 39.17540167], "line": {"color": "red", "width": 1}, "lon": [-80.29055556, -76.66819833], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.061269146608315096, "lat": [18.43941667, 39.17540167], "line": {"color": "red", "width": 1}, "lon": [-66.00183333, -76.66819833], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.3938730853391685, "lat": [32.89595056, 35.21401111], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -80.94312583], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.3041575492341357, "lat": [32.89595056, 38.80580556], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -104.70025], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.1137855579868709, "lat": [32.89595056, 39.90237583], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -84.219375], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.6433260393873085, "lat": [32.89595056, 38.85208333], "line": {"color": "red", "width": 1}, "lon": [-97.0372, -77.03772222], "locationmode": "USA-states", "type": "scattergeo"}, {"mode": "lines", "opacity": 0.12253829321663019, "lat": [25.79325, 39.85840806], "line": {"color": "red", "width ...
