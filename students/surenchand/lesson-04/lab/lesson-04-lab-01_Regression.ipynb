# %% [markdown]
# # Data Science Course Week 2 - Lesson 2
# # Introduction to Linear Regression

# %% [markdown]
# Regression is the process of learning a mapping from a vector of input data to a quantitative output given a set of observations. For example, coordinates in a room to Wi-Fi signal strength, someone's Body Mass Index to their life expectancy or a stock's performance over the last 5 days to it's value tomorrow.
#
# There are numerous methods for addressing this problem, each with their own set of assumptions and behaviour. Some are ideal for tackling large volumes of data while others provide more informative probabilistic outputs.
#
# In this lab, we'll focus on Linear Regression; a good point of reference for many other regression techniques and still used widely around the world today due to their simplicity and favourable scaling characteristics.

# %% [markdown]
# We will be using [statsmodels](http://statsmodels.sourceforge.net/devel/examples/notebooks/generated/ols.html) for learning about linear regression. It covers the models better than in scikit when we are learning and want more insights into the model parameters. But we will mainly be using scikit learn for the rest of the course.

# %% [markdown]
# # Class Workshop

# %%
# Import the libraries required
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %% [markdown]
# Here we are using a dataset of chicago house prices. The dataset is made up of houses that sold and several variables that describe the data.

# %%
# Read in data
house_data = pd.read_csv("chicagohouseprices2.csv", index_col=0)

# %% [markdown]
# # house_data.head()

# %%
# do we have any missing data?
house_data.isnull().sum()
# Out:
# Address             0
# Neighborhood        0
# HouseType           3
# Price               0
# Bath              149
# CrimeIndex          0
# MinutesToLoop       0
# MilesToLake         0
# Age                 0
# LotSizeSqft         0
# HouseSizeSqft       0
# SchoolIndex         0
# EstimatedPrice      0
# dtype: int64

# %%
clean_houes_data =house_data.loc[house_data['HouseSizeSqft'] != 0]
clean_houes_data
# Out:
#                                  Address Neighborhood           HouseType  \
# 2           2047 W Thomas St, Chicago IL  Wicker Park   Multi-Family Home
# 4           1634 W Beach Ave, Chicago IL  Wicker Park   Multi-Family Home
# 5        1634 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 8            1418 N Bell Ave, Chicago IL  Wicker Park   Multi-Family Home
# 9        1308 N Bosworth Ave, Chicago IL  Wicker Park   Multi-Family Home
# 10            1025 N Wood St, Chicago IL  Wicker Park   Multi-Family Home
# 11         1732 W Pierce Ave, Chicago IL  Wicker Park   Multi-Family Home
# 13        2116 W Potomac Ave, Chicago IL  Wicker Park   Multi-Family Home
# 14            1421 N Wood St, Chicago IL  Wicker Park  Single-Family Home
# 16        1411 N Ashland Ave, Chicago IL  Wicker Park   Multi-Family Home
# 17        1409 N Ashland Ave, Chicago IL  Wicker Park   Multi-Family Home
# 19           2152 W Caton St, Chicago IL  Wicker Park  Single-Family Home
# 20      1735 N Hermitage Ave, Chicago IL  Wicker Park  Single-Family Home
# 23     1725 W Le Moyne St #2, Chicago IL  Wicker Park   Multi-Family Home
# 26       922 N Hermitage Ave, Chicago IL  Wicker Park   Multi-Family Home
# 31     1610 N Winchester Ave, Chicago IL  Wicker Park  Single-Family Home
# 32           1357 N Bell Ave, Chicago IL  Wicker Park  Single-Family Home
# 33      1109 N Hermitage Ave, Chicago IL  Wicker Park   Multi-Family Home
# 35       2034 W Willow St #D, Chicago IL  Wicker Park            Townhome
# 37      1644 N Hermitage Ave, Chicago IL  Wicker Park   Multi-Family Home
# 38       1738 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 39      1456 N Milwaukee Ave, Chicago IL  Wicker Park   Multi-Family Home
# 43        1105 N Wolcott Ave, Chicago IL  Wicker Park            Townhome
# 45        1237 N Wolcott Ave, Chicago IL  Wicker Park   Multi-Family Home
# 46        1354 N Wolcott Ave, Chicago IL  Wicker Park            Townhome
# 49         1754 W Crystal St, Chicago IL  Wicker Park  Single-Family Home
# 52          1524 W Thomas St, Chicago IL  Wicker Park  Single-Family Home
# 53         1507 N Leavitt St, Chicago IL  Wicker Park  Single-Family Home
# 57         1744 N Wilmot Ave, Chicago IL  Wicker Park  Single-Family Home
# 58   1736 N Winnebago Ave #F, Chicago IL  Wicker Park            Townhome
# ..                                   ...          ...                 ...
# 90          2045 W Cortez St, Chicago IL  Wicker Park   Multi-Family Home
# 91       1517 W Augusta Blvd, Chicago IL  Wicker Park   Multi-Family Home
# 92         1500 N Paulina St, Chicago IL  Wicker Park  Single-Family Home
# 93     1118 N Winchester Ave, Chicago IL  Wicker Park  Single-Family Home
# 101         1236 N Hoyne Ave, Chicago IL  Wicker Park  Single-Family Home
# 102         1249 N Marion Ct, Chicago IL  Wicker Park  Single-Family Home
# 120    2008 W Potomac Ave #D, Chicago IL  Wicker Park            Townhome
# 121    1130 N Winchester Ave, Chicago IL  Wicker Park   Multi-Family Home
# 128     1522 N Elk Grove Ave, Chicago IL  Wicker Park  Single-Family Home
# 130     1435 N Elk Grove Ave, Chicago IL  Wicker Park  Single-Family Home
# 135      1924 W Wabansia Ave, Chicago IL  Wicker Park  Single-Family Home
# 142          1310 N Bell Ave, Chicago IL  Wicker Park  Single-Family Home
# 145          1321 N Bell Ave, Chicago IL  Wicker Park  Single-Family Home
# 146        1808 W Haddon Ave, Chicago IL  Wicker Park   Multi-Family Home
# 152         1747 W North Ave, Chicago IL  Wicker Park   Multi-Family Home
# 161         2245 W Cortez St, Chicago IL  Wicker Park   Multi-Family Home
# 162      1767 N Hoyne Ave #B, Chicago IL  Wicker Park            Townhome
# 165         1634 W Julian St, Chicago IL  Wicker Park   Multi-Family Home
# 166         1632 W Julian St, Chicago IL  Wicker Park   Multi-Family Home
# 167        1614 W Pierce Ave, Chicago IL  Wicker Park   Multi-Family Home
# 170       1916 W Potomac Ave, Chicago IL  Wicker Park  Single-Family Home
# 179     1511 N Paulina St #N, Chicago IL  Wicker Park            Townhome
# 182  1724 N Winnebago Ave #I, Chicago IL  Wicker Park            Townhome
# 189       1723 W Le Moyne St, Chicago IL  Wicker Park  Single-Family Home
# 190      1422 N Hoyne Ave #1, Chicago IL  Wicker Park   Multi-Family Home
# 194    1732 N Winchester Ave, Chicago IL  Wicker Park  Single-Family Home
# 198       1649 N Wolcott Ave, Chicago IL  Wicker Park                 NaN
# 199         2043 W Thomas St, Chicago IL  Wicker Park  Single-Family Home
# 200        1338 N Leavitt St, Chicago IL  Wicker Park  Single-Family Home
# 203        1928 W Crystal St, Chicago IL  Wicker Park   Multi-Family Home
#
#        Price  Bath  CrimeIndex  MinutesToLoop  MilesToLake  Age  LotSizeSqft  \
# 2     620000   4.0        2.09              9         3.84   94         3049
# 4     477000   2.0        4.63              9         2.96   31         2614
# 5     695000   2.0        1.40              8         2.86   23         2614
# 8     466000   2.0        4.93             10         4.02  121         3049
# 9     435000   2.0        4.75              8         2.89  119         3485
# 10    303000   2.0        4.68              8         3.43  119         3049
# 11    314000   3.0        5.18              9         3.06  131         2614
# 13    650000   3.0        3.89             10         3.86  119         3485
# 14    490500   1.0        5.38              9         3.21  124         2614
# 16    590000   2.0        4.50              8         2.90  118         2614
# 17    590000   2.0        4.50              8         2.90  119         2614
# 19    885000   3.0        5.58             11         3.72  121         4792
# 20    982500   3.0        4.65              9         2.98    0         2614
# 23    580000   3.0        5.18              9         3.08  108         2614
# 26    398000   2.0        4.23              8         3.42  116         3049
# 31   1050000   2.0        5.65              9         3.41  131         3049
# 32   1125000   2.0        4.93             10         4.03   21         3049
# 33    383500   2.0        5.38              8         3.29  128         3049
# 35    585000   3.0        5.58             11         3.46    0          871
# 37    460000   4.0        5.65              9         3.06  121         3049
# 38    675000   2.0        4.65              9         3.03  114         1742
# 39   2150000   4.0        6.09              8         3.35  128         3049
# 43    590000   2.0        3.29              9         3.56    0          871
# 45    647500   3.0        4.99              9         3.49  119         3920
# 46    500000   1.0        5.88              9         3.37    0         1742
# 49    695000   3.0        4.93              9         3.29    0         2614
# 52    326000   2.0        5.30              7         2.95  119         3049
# 53    245000   1.0        3.51             10         3.86  121         3485
# 57    770000   3.0        5.58             11         3.61    0         2614
# 58    462500   2.0        8.08             11         3.84    0          871
# ..       ...   ...         ...            ...          ...  ...          ...
# 90    405000   2.0        1.09             10         3.86  121         3049
# 91    434000   2.0        5.10              6         3.03  121         3049
# 92    870000   1.0        4.93              8         3.03   14         2614
# 93    495000   1.0        3.49              9         3.67  108         3049
# 101   650000   1.0        3.39             11         3.85   31         7405
# 102   730000   2.0        5.74              9         3.42    0         2614
# 120   490000   2.0        3.59             11         3.68    0         1307
# 121   655000   2.0        3.49              9         3.66  114         3485
# 128  1570000   4.0        5.79              8         3.33    0         3049
# 130  1550000   3.0        5.99              9         3.24    0         2614
# 135  1357000   2.0        4.65             10         3.33   16         3920
# 142   300000   1.0        4.93             11         4.08  127         3049
# 145   500000   1.0        4.93             11         4.05  119         3049
# 146   565000   4.0        4.88              9         3.40  131         2178
# 152   390000   3.0        5.78              8         3.10  131         2614
# 161   350000   2.0        1.96             10         4.20   99         3920
# 162   515000   2.0        5.58             11         3.55    0          871
# 165   581000   3.0        4.63              9         2.94  121         2614
# 166   581000   3.0        4.63              9         2.94  121         2614
# 167   625000   3.0        4.43              8         2.87  123         2614
# 170   722000   2.0        4.99             10         3.52   21         3049
# 179   368500   1.0        4.93              8         3.01    0          871
# 182   305000   2.0        8.08             11         3.83    0          436
# 189   610000   1.0        5.18              9         3.08  115         2614
# 190   624000   3.0        3.89             10         3.76  109         3485
# 194  1300000   3.0        4.65             10         3.35    0         3049
# 198   660000   3.0        5.65             10         3.29  118         2614
# 199   680000   1.0        2.09              9         3.83  111         3049
# 200   322000   1.0        3.76             10         3.97  126         3049
# 203   580000   3.0        4.99              9         3.56  119         3049
#
#      HouseSizeSqft  SchoolIndex  EstimatedPrice
# 2             3492         36.2        629300.0
# 4             1840         78.9        463644.0
# 5             1628         50.0        813150.0
# 8             1344         16.7        538696.0
# 9             1760         40.0        463275.0
# 10            2728         59.5        361782.0
# 11            2405         50.0        334724.0
# 13            3618         16.7        680550.0
# 14             922         69.4        516987.0
# 16            2544         78.9        589410.0
# 17            2352         78.9        644870.0
# 19            3461         36.1        945180.0
# 20            2783         33.3       1087627.5
# 23            2656         50.0        596820.0
# 26            1344         22.2        364170.0
# 31            2580         69.4       1050000.0
# 32            1290         16.7       1105875.0
# 33            2763         59.5        409961.5
# 35            1983         36.1        539955.0
# 37            2856         33.3        541880.0
# 38            2279         33.3        654750.0
# 39            6422         69.4       2386500.0
# 43            2183         59.5        575250.0
# 45            4125         59.5        530950.0
# 46            2040         69.4        512000.0
# 49            2403         59.5        729750.0
# 52            1089         27.3        298942.0
# 53             861         93.9        263130.0
# 57            2997         36.1        623700.0
# 58            1436         36.1        515225.0
# ..             ...          ...             ...
# 90            2016         36.2        341415.0
# 91            1512         22.2        471758.0
# 92            1996         50.0        936120.0
# 93            1958         59.5        506880.0
# 101            900         69.4        737750.0
# 102           2420         59.5        686930.0
# 120           1328         69.4        560560.0
# 121           1484         59.5        641900.0
# 128           3276         69.4       1342350.0
# 130           2620         69.4       1464750.0
# 135           2311         36.1       1394996.0
# 142           1512         40.8        280200.0
# 145           1560         16.7        520000.0
# 146           2200         59.5        580255.0
# 152           2596         50.0        399360.0
# 161           2652         33.3        307300.0
# 162           1754         36.1        563410.0
# 165           3432         50.0        611212.0
# 166           2646         50.0        664083.0
# 167           3360         50.0        705625.0
# 170           2349         69.4        777594.0
# 179            935         50.0        397243.0
# 182            918         36.1        316895.0
# 189            392         50.0        724680.0
# 190           3663         69.4        643344.0
# 194           3043         36.1       1210300.0
# 198           2777         33.3        753720.0
# 199           1214         36.2        635120.0
# 200           1260         16.7        283682.0
# 203           3612         59.5        657140.0
#
# [69 rows x 13 columns]

# %%
# Summarise the data
#clean_houes_data.describe()
#house_data.describe(include=['object'])
house_data.describe(include='all')
# Out:
#                                   Address Neighborhood HouseType  \
# count                                 219          219       216
# unique                                219            1         5
# top     1028 N Wolcott Ave #1, Chicago IL  Wicker Park     Condo
# freq                                    1          219       146
# mean                                  NaN          NaN       NaN
# std                                   NaN          NaN       NaN
# min                                   NaN          NaN       NaN
# 25%                                   NaN          NaN       NaN
# 50%                                   NaN          NaN       NaN
# 75%                                   NaN          NaN       NaN
# max                                   NaN          NaN       NaN
#
#                Price       Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# count   2.190000e+02  70.000000  219.000000     219.000000   219.000000
# unique           NaN        NaN         NaN            NaN          NaN
# top              NaN        NaN         NaN            NaN          NaN
# freq             NaN        NaN         NaN            NaN          NaN
# mean    4.834311e+05   2.271429    4.663607       9.698630     3.420411
# std     4.001249e+05   0.883364    1.418146       2.898995     0.352522
# min     2.450000e+04   1.000000    1.090000       6.000000     2.770000
# 25%     3.190000e+05   2.000000    3.940000       8.000000     3.150000
# 50%     3.900000e+05   2.000000    4.930000       9.000000     3.400000
# 75%     5.125000e+05   3.000000    5.580000      10.000000     3.685000
# max     3.686000e+06   4.000000    8.080000      22.000000     4.200000
#
#                Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  EstimatedPrice
# count   219.000000   219.000000     219.000000   219.000000    2.190000e+02
# unique         NaN          NaN            NaN          NaN             NaN
# top            NaN          NaN            NaN          NaN             NaN
# freq           NaN          NaN            NaN          NaN             NaN
# mean     29.424658   873.200913     699.977169    49.197717    4.862191e+05
# std      49.155880  1392.893683    1175.278922    18.554525    3.978582e+05
# min       0.000000     0.000000       0.000000    16.700000    2.883650e+04
# 25%       0.000000     0.000000       0.000000    36.100000    3.074488e+05
# 50%       0.000000     0.000000       0.000000    50.000000    3.919800e+05
# 75%      41.000000  2614.000000    1344.000000    59.500000    5.324750e+05
# max     131.000000  7405.000000    6422.000000    93.900000    3.973508e+06

# %%
# Look for any linear correlations in the data
clean_houes_data.corr()
# Out:
#                    Price      Bath  CrimeIndex  MinutesToLoop  MilesToLake  \
# Price           1.000000  0.108621    0.187523       0.088478    -0.135279
# Bath            0.108621  1.000000    0.166094       0.163833    -0.148545
# CrimeIndex      0.187523  0.166094    1.000000       0.118140    -0.206527
# MinutesToLoop   0.088478  0.163833    0.118140       1.000000     0.411211
# MilesToLake    -0.135279 -0.148545   -0.206527       0.411211     1.000000
# Age            -0.060809 -0.024026   -0.177836      -0.146572    -0.067629
# LotSizeSqft     0.141553 -0.034063   -0.351145      -0.028382     0.188221
# HouseSizeSqft   0.217252  0.753694    0.062150       0.092728    -0.076090
# SchoolIndex    -0.037443 -0.039038   -0.045369      -0.174636    -0.216786
# EstimatedPrice  0.985328  0.103225    0.190961       0.085460    -0.153555
#
#                      Age  LotSizeSqft  HouseSizeSqft  SchoolIndex  \
# Price          -0.060809     0.141553       0.217252    -0.037443
# Bath           -0.024026    -0.034063       0.753694    -0.039038
# CrimeIndex     -0.177836    -0.351145       0.062150    -0.045369
# MinutesToLoop  -0.146572    -0.028382       0.092728    -0.174636
# MilesToLake    -0.067629     0.188221      -0.076090    -0.216786
# Age             1.000000     0.354108       0.114106    -0.065042
# LotSizeSqft     0.354108     1.000000       0.169814     0.064398
# HouseSizeSqft   0.114106     0.169814       1.000000     0.136774
# SchoolIndex    -0.065042     0.064398       0.136774     1.000000
# EstimatedPrice -0.048662     0.146176       0.224732    -0.023922
#
#                 EstimatedPrice
# Price                 0.985328
# Bath                  0.103225
# CrimeIndex            0.190961
# MinutesToLoop         0.085460
# MilesToLake          -0.153555
# Age                  -0.048662
# LotSizeSqft           0.146176
# HouseSizeSqft         0.224732
# SchoolIndex          -0.023922
# EstimatedPrice        1.000000

# %%
# Plot each variable against each other 
# scroll down past the subplot information
pd.scatter_matrix(clean_houes_data, figsize=(15,15))
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:3: FutureWarning: pandas.scatter_matrix is deprecated. Use pandas.plotting.scatter_matrix instead
#   This is separate from the ipykernel package so we can avoid doing imports until
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fe045780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fc007240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fc028da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbfce860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbfef240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbf8cd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbfb4978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbf58588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbefd128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbf1a748>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbf2e390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbeddeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbe81a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbe91470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbe46898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbe6a4a8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbe0f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbe2fc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbdd02e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbdef358>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbd94eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbd37eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbd59a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbcfcac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbd21ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbcc4ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbd33390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbc88668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbcae668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbc52668>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbc74ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbc180b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbbbb0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbbde0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbb825f8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbb9aa58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbb429e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbb669e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbb08f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbb10dd8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbad2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fbaf3518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fba97a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fba3b9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fba54eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb9f8e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fba1e320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb9c3dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fba26d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb9870f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb9aa4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb94d4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb970470>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb9110f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb8b5160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb8da0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb875fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb88b438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb83cb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb85de10>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb873438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb828d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb7c9550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb7ed630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb792630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb736630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb79fba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb6fc160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb721160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb6c20f0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb6e6630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb683b00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb6a7a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb6489b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb66e9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb68c128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb6341d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb5d7240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb57c160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb5a0160>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb538cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb564160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb509160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb52c0f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb4c5cc0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb4ead30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb491c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb4b3c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb4a33c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb3fa8d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb41d8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb3c28d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb3e5d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb387390>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb3ad320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb34f240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb362550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb391ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb32ab70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f12fb2ccb00>]],
#       dtype=object)

# %% [markdown]
# ### Questions?
#
# - Can you describe the data set - give a summary of what's happening?
# - What looks to be affecting house prices from our initial inspection?
# - What is the type of relationship in those variables affecting price?

# %%
# create a fitted model in one line
lm = smf.ols(formula='Price ~ Bath + HouseSizeSqft', data=house_data).fit()

# print the coefficients!
lm.params
# Out:
# Intercept        508310.776747
# Bath             -28995.658012
# HouseSizeSqft       133.011874
# dtype: float64

# %% [markdown]
# The summary function provided by the statsmodel library presents lots of useful information about the resulting model.
#
# Key items to pay attention to are:
# - R-squared
# - Adj. R-Squared
# - coef (for each variable)

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.010
# Method:                 Least Squares   F-statistic:                     1.340
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):              0.269
# Time:                        14:04:26   Log-Likelihood:                -1030.2
# No. Observations:                  70   AIC:                             2066.
# Df Residuals:                      67   BIC:                             2073.
# Df Model:                           2
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept      5.083e+05   2.05e+05      2.478      0.016    9.89e+04    9.18e+05
# Bath            -2.9e+04   1.16e+05     -0.250      0.803   -2.61e+05    2.03e+05
# HouseSizeSqft   133.0119     99.854      1.332      0.187     -66.297     332.321
# ==============================================================================
# Omnibus:                       85.337   Durbin-Watson:                   1.175
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              891.863
# Skew:                           3.754   Prob(JB):                    2.16e-194
# Kurtosis:                      18.793   Cond. No.                     7.19e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.19e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# What would you expect a house price to be for a house with 3 bathrooms and 350 sqft?
# Calculate it.
508310 -28995.66*3 + 133*350
# Out:
# 467873.02

# %% [markdown]
# ## Student Excercise

# %% [markdown]
# Now try creating a regression from just the EstimatedPrice

# %%
# check the distribution of Price vs. EstimatedPrice using a scatterplot
import seaborn as sns
sns.set_style("darkgrid")

sns.lmplot(y='Price', x='EstimatedPrice', data=house_data)

# %%
# Let's try just modelling just using the estimated price
# create a fitted model in one line
lm = smf.ols(formula='Price ~ EstimatedPrice ', data=house_data).fit()

# print the coefficients
lm.params
# Out:
# Intercept         2371.037940
# EstimatedPrice       0.989389
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.968
# Model:                            OLS   Adj. R-squared:                  0.968
# Method:                 Least Squares   F-statistic:                     6529.
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):          6.25e-164
# Time:                        14:05:55   Log-Likelihood:                -2758.9
# No. Observations:                 219   AIC:                             5522.
# Df Residuals:                     217   BIC:                             5529.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept       2371.0379   7685.764      0.308      0.758   -1.28e+04    1.75e+04
# EstimatedPrice     0.9894      0.012     80.801      0.000       0.965       1.014
# ==============================================================================
# Omnibus:                      198.218   Durbin-Watson:                   2.238
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             8006.566
# Skew:                           3.156   Prob(JB):                         0.00
# Kurtosis:                      31.941   Cond. No.                     9.93e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 9.93e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# ### Question:
# Did the model build on just Estimated Price have a better R-Squared value than the prior model built using Bath and HouseSizeSqft?

# %% [markdown]
# ### Predicting Price using the built model

# %% [markdown]
# Now we will find out what the model estimates the price will be for the the minimum and maximium values of EstimatedPrice

# %%
# create a DataFrame with the minimum and maximum values of EstimatedPrice
# these values will be be used in the built model to predict the Price
X_new = pd.DataFrame({'EstimatedPrice': [house_data.EstimatedPrice.min(), house_data.EstimatedPrice.max()]})
X_new.head()
# Out:
#    EstimatedPrice
# 0         28836.5
# 1       3973508.0

# %%
# predict price given two data points and the built model

preds = lm.predict(X_new)
preds
# Out:
# 0    3.090156e+04
# 1    3.933717e+06
# dtype: float64

# %% [markdown]
# Now lets view a line representing the model build off just Estimated Price, over a scatter plot of the data of Price vs. EstimatedPrice.
#
# To produce the line overlay, we will simply plot a straight line between the two predicted points over the scatter plot.

# %%
# first, plot the observed data
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')

# %%
# Now, plot a line over the points that uses just the two points
house_data.plot(kind='scatter', x='EstimatedPrice', y='Price')
# this code overlays a straight line between the the coordinates created by X_new and preds
plt.plot(X_new, preds, c='red', linewidth=2)

# %% [markdown]
# ### Experiment
# Now try creating new models by selecting different variables or combinations of variables. Can you get a better fit?

# %% [markdown]
# ## Themepark

# %% [markdown]
# The file **themepark.csv** has some data from a theme park. Children were asked to rate their experience on a scale
# from 0-5. This data was compared against the number of hours they spent in the park.

# %%
# !ls
# Out:
# anscombe.csv		 drinks.csv			    themepark.csv
# chicagohouseprices2.csv  lesson-04-lab-01_Regression.ipynb

# %%
# Create a pandas DataFrame from this data by reading it in using pandas. 
# It is located in the same directory as this notebook, so you will not need to provide a filepath.
themepark_data = pd.read_csv("themepark.csv")

# %%
# Have a look at the data (e.g. display the head or tail, use describe, etc.)
themepark_data.head
# Out:
# <bound method NDFrame.head of     Hours  Enjoyment
# 0       1          1
# 1       2          3
# 2       3          4
# 3       4          5
# 4       5          5
# 5       1          0
# 6       1          1
# 7       1          0
# 8       1          3
# 9       1          2
# 10      1          1
# 11      2          2
# 12      2          2
# 13      2          4
# 14      2          4
# 15      2          3
# 16      3          3
# 17      3          2
# 18      3          3
# 19      3          4
# 20      3          5
# 21      4          4
# 22      4          5
# 23      5          5
# 24      5          5
# 25      5          5
# 26      5          4>

# %%
# Draw a scatterplot of this data.
themepark_data.plot(kind='scatter', x='Hours', y='Enjoyment')

# %%
# Try doing a linear regression on this data
lm = smf.ols(formula='Enjoyment ~ Hours', data=themepark_data).fit()

# %%
lm.params
# Out:
# Intercept    0.663087
# Hours        0.906711
# dtype: float64

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Enjoyment   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.660
# Method:                 Least Squares   F-statistic:                     51.47
# Date:                Sat, 03 Mar 2018   Prob (F-statistic):           1.61e-07
# Time:                        14:22:18   Log-Likelihood:                -35.570
# No. Observations:                  27   AIC:                             75.14
# Df Residuals:                      25   BIC:                             77.73
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6631      0.391      1.697      0.102      -0.142       1.468
# Hours          0.9067      0.126      7.174      0.000       0.646       1.167
# ==============================================================================
# Omnibus:                        0.596   Durbin-Watson:                   1.507
# Prob(Omnibus):                  0.742   Jarque-Bera (JB):                0.660
# Skew:                           0.138   Prob(JB):                        0.719
# Kurtosis:                       2.285   Cond. No.                         7.25
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# Plot this regression over the top of the data. Could the regression be better?
sns.lmplot(y='Enjoyment', x='Hours', data=themepark_data)
